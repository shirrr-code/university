# %% [markdown]
# <a href="https://colab.research.google.com/github/shirrr-code/university/blob/main/Tasks/first_programm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
print('Hello MIIGAiK')
# Out:
# Hello World
# Hello MIIGAiK
